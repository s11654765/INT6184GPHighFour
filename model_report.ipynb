# %% [markdown]
# ## 肥胖等级分类（作业汇报版）
#
# - **分步运行（推荐课堂演示）**：打开同目录 **`model.ipynb`**，按单元格从上到下依次运行（与 `model.py` 逻辑一致）。
# - **一键跑通脚本**：见下方 `%run model.py`；或在终端：`py -3 model.py`（勿用可能无输出的 Windows 商店占位 `python`）。
#
# 数据：`Obesity_Data_clean_onehot.xlsx`（已编码）。重新生成笔记本可运行：`py -3 _build_model_ipynb.py`。

# %%
# 导入部分仅保留必要语句；完整建模流程在 model.py 中（除 import 外均有中文注释）
# %run model.py
